# %%
from numpy import load
import numpy as np

# %%
data = load('output/tadpoleDf2.npz', allow_pickle = True)

# %%
for item in data:
    print(item)
# Out:
# data
# diag
# labels
# scanTimepts
# partCode
# ageAtScan
# dataDf
# monthsSinceRefTime
# examDates
# predInd

# %%
print(data)
# Out:
# {'data': array([[  1.36926,       nan,       nan, ...,       nan,       nan,
#               nan],
#        [  1.09079,       nan,       nan, ..., 741.5    , 239.7    ,
#          22.83   ],
#        [  1.0636 ,       nan,       nan, ...,       nan,       nan,
#               nan],
#        ...,
#        [      nan,       nan,       nan, ...,       nan,       nan,
#               nan],
#        [      nan,       nan,       nan, ...,       nan,       nan,
#               nan],
#        [      nan,       nan,       nan, ...,       nan,       nan,
#               nan]]), 'diag': array([1., 3., 3., ..., 2., 2., 2.]), 'labels': array([b'FDG', b'PIB', b'AV45', ..., b'ABETA_UPENNBIOMK9_04_19_17',
#        b'TAU_UPENNBIOMK9_04_19_17', b'PTAU_UPENNBIOMK9_04_19_17'],
#       dtype='|S100'), 'scanTimepts': array([ 0.,  0.,  1., ...,  8.,  7., 10.]), 'partCode': array([   2,    3,    3, ..., 4557, 4512, 2380]), 'ageAtScan': array([74.3       , 81.3       , 81.79863014, ..., 88.30273973,
# ...

# %%
for key, value in data.items():
    np.savetxt("output" + key + ".csv", value)
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# /anaconda3/envs/dive_tadpole/lib/python3.7/site-packages/numpy/lib/npyio.py in savetxt(fname, X, fmt, delimiter, newline, header, footer, comments, encoding)
#    1428                 try:
# -> 1429                     v = format % tuple(row) + newline
#    1430                 except TypeError:
#
# TypeError: must be real number, not numpy.bytes_
#
# During handling of the above exception, another exception occurred:
#
# TypeError                                 Traceback (most recent call last)
# <ipython-input-6-595c2901be79> in <module>
#       1 for key, value in data.items():
# ----> 2     np.savetxt("output" + key + ".csv", value)
#
# /anaconda3/envs/dive_tadpole/lib/python3.7/site-packages/numpy/lib/npyio.py in savetxt(fname, X, fmt, delimiter, newline, header, footer, comments, encoding)
# ...
